# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bc = pd.read_csv('F:\Kaggle\cs-test.csv')

# %%
bc.head(30)
# Out:
#     Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1               NaN                              0.885519   43
# 1            2               NaN                              0.463295   57
# 2            3               NaN                              0.043275   59
# 3            4               NaN                              0.280308   38
# 4            5               NaN                              1.000000   27
# 5            6               NaN                              0.509791   63
# 6            7               NaN                              0.587778   50
# 7            8               NaN                              0.046149   79
# 8            9               NaN                              0.013527   68
# 9           10               NaN                              1.000000   23
# 10          11               NaN                              0.028485   37
# ...

# %%
bc.dtypes
# Out:
# Unnamed: 0                                int64
# SeriousDlqin2yrs                        float64
# RevolvingUtilizationOfUnsecuredLines    float64
# age                                       int64
# NumberOfTime30-59DaysPastDueNotWorse      int64
# DebtRatio                               float64
# MonthlyIncome                           float64
# NumberOfOpenCreditLinesAndLoans           int64
# NumberOfTimes90DaysLate                   int64
# NumberRealEstateLoansOrLines              int64
# NumberOfTime60-89DaysPastDueNotWorse      int64
# NumberOfDependents                      float64
# dtype: object

# %%
bc['SeriousDlqin2yrs']=bc['SeriousDlqin2yrs'].fillna(0)

# %%
bc['RevolvingUtilizationOfUnsecuredLines'].head(51)
# Out:
# 0     0.885519
# 1     0.463295
# 2     0.043275
# 3     0.280308
# 4     1.000000
# 5     0.509791
# 6     0.587778
# 7     0.046149
# 8     0.013527
# 9     1.000000
# 10    0.028485
# 11    0.085077
# 12    0.010596
# 13    0.380679
# 14    0.556894
# 15    0.079056
# 16    0.543013
# 17    0.112346
# 18    0.648285
# 19    0.686406
# 20    0.085910
# 21    0.158549
# 22    0.009303
# 23    0.957442
# 24    0.442489
# 25    0.125267
# 26    1.000000
# 27    0.181481
# 28    0.729397
# 29    0.024445
# 30    0.691411
# 31    0.000000
# 32    0.000000
# 33    0.817480
# 34    1.008267
# 35    0.423358
# 36    0.282515
# 37    0.142127
# 38    0.022738
# 39    0.005893
# 40    0.603510
# 41    0.715499
# 42    0.640014
# 43    0.025266
# 44    0.190885
# 45    0.003449
# 46    0.013049
# 47    0.222961
# 48    0.019542
# 49    0.524461
# 50    0.083717
# Name: RevolvingUtilizationOfUnsecuredLines, dtype: float64

# %%
bc.isnull().sum()
# Out:
# Unnamed: 0                                  0
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           20103
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       2626
# dtype: int64

# %%
bc['MonthlyIncome']=bc['MonthlyIncome'].fillna(0)

# %%
bc.head(15)
# Out:
#     Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                 0                              0.885519   43
# 1            2                 0                              0.463295   57
# 2            3                 0                              0.043275   59
# 3            4                 0                              0.280308   38
# 4            5                 0                              1.000000   27
# 5            6                 0                              0.509791   63
# 6            7                 0                              0.587778   50
# 7            8                 0                              0.046149   79
# 8            9                 0                              0.013527   68
# 9           11                 0                              0.028485   37
# 10          12                 0                              0.085077   52
# ...

# %%
#Limite em DebtRation, valores muitos altos como Outliers.Podendo ser um erro de cadastro, em comum a renda fixa do usario com o limite que ele possa gastar.
#Exemplo: ele ganha R$5000 e tem um divida de Milhões, ou um erro de preenchimento no sistema onde o usuário não informou sua renda.
#Também criando uma coluna nova chamada 'Limite_DebtRatio' para todos os valores do limite_aceitavel(0.274230103) como  1.
limite = 1.0

# %%
limite_aceitavel=bc.loc[bc['DebtRatio'] <= limite, 'DebtRatio'].median()

# %%
limite_aceitavel
# Out:
# 0.274230103

# %%
bc.loc[bc['DebtRatio'] > limite, 'DebtRatio'] = limite_aceitavel

# %%
bc['Limite_DebtRatio'] = (bc['DebtRatio'] == 0.274230103).astype(int)

# %%
bc.head(10)
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1               0.0                              0.885519   43
# 1           2               0.0                              0.463295   57
# 2           3               0.0                              0.043275   59
# 3           4               0.0                              0.280308   38
# 4           5               0.0                              1.000000   27
# 5           6               0.0                              0.509791   63
# 6           7               0.0                              0.587778   50
# 7           8               0.0                              0.046149   79
# 8           9               0.0                              0.013527   68
# 9          10               0.0                              1.000000   23
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     0   0.177513         5700.0
# ...

# %%
bc[bc['SeriousDlqin2yrs'] ==0].head(15)
# Out:
#     Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                 0                              0.885519   43
# 1            2                 0                              0.463295   57
# 2            3                 0                              0.043275   59
# 3            4                 0                              0.280308   38
# 4            5                 0                              1.000000   27
# 5            6                 0                              0.509791   63
# 6            7                 0                              0.587778   50
# 7            8                 0                              0.046149   79
# 8            9                 0                              0.013527   68
# 9           11                 0                              0.028485   37
# 10          12                 0                              0.085077   52
# ...

# %%
bc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101503 entries, 0 to 101502
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Unnamed: 0                            101503 non-null  int64
#  1   SeriousDlqin2yrs                      101503 non-null  float64
#  2   RevolvingUtilizationOfUnsecuredLines  101503 non-null  float64
#  3   age                                   101503 non-null  int64
#  4   NumberOfTime30-59DaysPastDueNotWorse  101503 non-null  int64
#  5   DebtRatio                             101503 non-null  float64
#  6   MonthlyIncome                         101503 non-null  float64
#  7   NumberOfOpenCreditLinesAndLoans       101503 non-null  int64
#  8   NumberOfTimes90DaysLate               101503 non-null  int64
#  9   NumberRealEstateLoansOrLines          101503 non-null  int64
# ...

# %%
bc.head(50)
# Out:
#     Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                 0                              0.885519   43
# 1            2                 0                              0.463295   57
# 2            3                 0                              0.043275   59
# 3            4                 0                              0.280308   38
# 4            5                 0                              1.000000   27
# 5            6                 0                              0.509791   63
# 6            7                 0                              0.587778   50
# 7            8                 0                              0.046149   79
# 8            9                 0                              0.013527   68
# 9           11                 0                              0.028485   37
# 10          12                 0                              0.085077   52
# ...

# %%
bc.dtypes
# Out:
# Unnamed: 0                                int64
# SeriousDlqin2yrs                        float64
# RevolvingUtilizationOfUnsecuredLines    float64
# age                                       int64
# NumberOfTime30-59DaysPastDueNotWorse      int64
# DebtRatio                               float64
# MonthlyIncome                           float64
# NumberOfOpenCreditLinesAndLoans           int64
# NumberOfTimes90DaysLate                   int64
# NumberRealEstateLoansOrLines              int64
# NumberOfTime60-89DaysPastDueNotWorse      int64
# NumberOfDependents                      float64
# dtype: object

# %%
bc['SeriousDlqin2yrs']=bc['SeriousDlqin2yrs'].astype(int)

# %%
bc.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  101503.000000          101503.0                         101503.000000
# mean    50752.000000               0.0                              5.310000
# std     29301.536524               0.0                            196.156039
# min         1.000000               0.0                              0.000000
# 25%     25376.500000               0.0                              0.030131
# 50%     50752.000000               0.0                              0.152586
# 75%     76127.500000               0.0                              0.564225
# max    101503.000000               0.0                          21821.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  101503.000000                         101503.000000  101503.000000
# mean       52.405436                              0.453770       0.295642
# ...

# %%
# Na coluna 'RevolvingUtilizationOfUnsecuredLines' é notavel valores muito acima do normal podendo ser outliers.
#  Para o tratamento deles irei limitar em 1.0 como o máximo todos valores acima de 1.0 .
#  Exemplo o número 21821 sendo uns dos maiores valores, assim se trasnformando em 1.0 .

# %%
limite = 1.0
limite_aceitavel1=bc.loc[bc['RevolvingUtilizationOfUnsecuredLines'] <= limite, 'RevolvingUtilizationOfUnsecuredLines'].median()

# %%
limite_aceitavel1
# Out:
# 0.14312798049999997

# %%
bc.loc[bc['RevolvingUtilizationOfUnsecuredLines'] > limite, 'RevolvingUtilizationOfUnsecuredLines'] = limite_aceitavel1

# %%
bc.head(15)
# Out:
#     Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                 0                              0.885519   43
# 1            2                 0                              0.463295   57
# 2            3                 0                              0.043275   59
# 3            4                 0                              0.280308   38
# 4            5                 0                              1.000000   27
# 5            6                 0                              0.509791   63
# 6            7                 0                              0.587778   50
# 7            8                 0                              0.046149   79
# 8            9                 0                              0.013527   68
# 9           11                 0                              0.028485   37
# 10          12                 0                              0.085077   52
# ...

# %%
bc.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  101503.000000          101503.0                         101503.000000
# mean    50752.000000               0.0                              0.301648
# std     29301.536524               0.0                              0.336597
# min         1.000000               0.0                              0.000000
# 25%     25376.500000               0.0                              0.030131
# 50%     50752.000000               0.0                              0.143128
# 75%     76127.500000               0.0                              0.512501
# max    101503.000000               0.0                              1.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  101503.000000                         101503.000000  101503.000000
# mean       52.405436                              0.453770       0.295642
# ...

# %%
# Outliers em 'NumberOfTime30-59DaysPastDueNotWorse' é notavel que o valor 98 e 96 aparecem frequentemente comparado aos outros, oque poderia ser impossivel,
#por conta que o usuário mesmo tendo 3 ou 4 cartões, chegar em 98 em dois anos não seria possivel, só se o usuário tevesse centenas de cartões e todos
#atrasados em uma quantidade exata.
# SOLUÇÃO= encotrar o 0.1% NumberOfTime30-59DaysPastDueNotWorse' que seria 19 o máximo que uma pessoa pode atrasar e limitar todos resto acima de 20
#para 20
limite_aceitavel2=20
bc.loc[bc['NumberOfTime30-59DaysPastDueNotWorse'] > limite_aceitavel2, 'NumberOfTime30-59DaysPastDueNotWorse'] = 20

# %%
#De outra forma
#bc['NumberOfTime30-59DaysPastDueNotWorse']=bc['NumberOfTime30-59DaysPastDueNotWorse'].clip(upper=20)

# %%
bc[bc['NumberOfTime30-59DaysPastDueNotWorse'].between(13,98)].sort_values(by='NumberOfTime30-59DaysPastDueNotWorse').head(10)
# Out:
#        Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 58279       58280                 0                              0.143128
# 9              10                 0                              1.000000
# 307           308                 0                              1.000000
# 69             70                 0                              1.000000
# 1131         1132                 0                              1.000000
# 1166         1167                 0                              1.000000
# 1176         1177                 0                              1.000000
# 703           704                 0                              1.000000
# 1924         1925                 0                              1.000000
# 2265         2266                 0                              1.000000
#
#        age  NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 58279   45                                    19   0.274230            0.0
# ...

# %%
bc.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  101503.000000          101503.0                         101503.000000
# mean    50752.000000               0.0                              0.301648
# std     29301.536524               0.0                              0.336597
# min         1.000000               0.0                              0.000000
# 25%     25376.500000               0.0                              0.030131
# 50%     50752.000000               0.0                              0.143128
# 75%     76127.500000               0.0                              0.512501
# max    101503.000000               0.0                              1.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  101503.000000                         101503.000000  101503.000000
# mean       52.405436                              0.289341       0.295642
# ...

# %%
# Removendo linha 55034 da tabela 'NumberOfOpenCreditLinesAndLoans' com valor de 85 sendo um valor impossivel para um usuário ter créditos e emprestimos ativos as mesmo tempo, mesmo sendo uma pessoa
#muito rica não seria possivel, e permanecendo com o restdo dos valores.
# Usando tambem um limitar em 65 como o valor mais próximo e válido dentro da tabela 'NumberOfOpenCreditLinesAndLoans'.

# %%
bc.loc[bc['NumberOfOpenCreditLinesAndLoans'] > 0, 'NumberOfOpenCreditLinesAndLoans'].median()
# Out:
# 8.0

# %%
linha_outlier = bc[bc['NumberOfOpenCreditLinesAndLoans'] == 85].index

# %%
linha_outlier
# Out:
# Index([55034], dtype='int64')

# %%
bc=bc.drop(linha_outlier)

# %%
bc.loc[bc['NumberOfOpenCreditLinesAndLoans'] == 85]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, SeriousDlqin2yrs, RevolvingUtilizationOfUnsecuredLines, age, NumberOfTime30-59DaysPastDueNotWorse, DebtRatio, MonthlyIncome, NumberOfOpenCreditLinesAndLoans, NumberOfTimes90DaysLate, NumberRealEstateLoansOrLines, NumberOfTime60-89DaysPastDueNotWorse, NumberOfDependents]
# Index: []

# %%
bc.loc[bc['NumberOfOpenCreditLinesAndLoans']>= 65].sort_values(by='NumberOfOpenCreditLinesAndLoans').head(55)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, SeriousDlqin2yrs, RevolvingUtilizationOfUnsecuredLines, age, NumberOfTime30-59DaysPastDueNotWorse, DebtRatio, MonthlyIncome, NumberOfOpenCreditLinesAndLoans, NumberOfTimes90DaysLate, NumberRealEstateLoansOrLines, NumberOfTime60-89DaysPastDueNotWorse, NumberOfDependents]
# Index: []

# %%
limite_NumberOfOpenCreditLinesAndLoans= 65

# %%
bc.loc[bc['NumberOfOpenCreditLinesAndLoans'] > limite_NumberOfOpenCreditLinesAndLoans, 'NumberOfOpenCreditLinesAndLoans'] =65

# %%
bc.head(15)
# Out:
#     Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                 0                              0.885519   43
# 1            2                 0                              0.463295   57
# 2            3                 0                              0.043275   59
# 3            4                 0                              0.280308   38
# 4            5                 0                              1.000000   27
# 5            6                 0                              0.509791   63
# 6            7                 0                              0.587778   50
# 7            8                 0                              0.046149   79
# 8            9                 0                              0.013527   68
# 9           11                 0                              0.028485   37
# 10          12                 0                              0.085077   52
# ...

# %%
# Visualizando tabela 'MonthlyIncome',Converter os valores 0 para NaN(Apenas se souber se a renda é realmente é 0), Então criar uma nova tabela de 0 e 1
#com o nome 'MonthlyIncome_Modificada' para que todas as linhas em NaN em 'MonthlyIncome' sejam informadas na nova tabela como 0 (informando renda) e 
#1 não informando renda.

# %%
bc['MonthlyIncome']=bc['MonthlyIncome'].replace(0,np.nan)

# %%
bc['MonthlyIncome_Modificada']=bc['MonthlyIncome'].isna().astype(int)

# %%
media_renda1=bc['MonthlyIncome'].median()

# %%
bc['MonthlyIncome']=bc['MonthlyIncome'].fillna(media_renda1)

# %%
bc.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  101502.000000          101502.0                         101502.000000
# mean    50751.957804               0.0                              0.301650
# std     29301.677781               0.0                              0.336598
# min         1.000000               0.0                              0.000000
# 25%     25376.250000               0.0                              0.030131
# 50%     50751.500000               0.0                              0.143128
# 75%     76127.750000               0.0                              0.512504
# max    101503.000000               0.0                              1.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  101502.000000                         101502.000000  101502.000000
# mean       52.405490                              0.289344       0.295642
# ...

# %%
bc.loc[bc['NumberOfTimes90DaysLate'] >=50].sort_values(by='NumberOfTimes90DaysLate').head(50)
# Out:
#        Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 14534       14535                 0                                   1.0
# 9              10                 0                                   1.0
# 307           308                 0                                   1.0
# 69             70                 0                                   1.0
# 1131         1132                 0                                   1.0
# 1166         1167                 0                                   1.0
# 1176         1177                 0                                   1.0
# 703           704                 0                                   1.0
# 1924         1925                 0                                   1.0
# 2265         2266                 0                                   1.0
# 2667         2668                 0                                   1.0
# 3088         3089                 0                                   1.0
# ...

# %%
#  Em 'NumberOfTimes90DaysLate' notamos que existe valores com uma variação muito alta, Criaremos uma nova tabela chamada 'Sentinela90_atrasado',
#com finalidade em pegar os valores 96 e 98 onde ocorre a maior variação desde o 18, sendo assim 96 e 98 sendo 1 e o resto 0.
#  Na tabela principal 'NumberOfTimes90DaysLate' os valores que tem como 96 e 98 deixar em NaN, para não interferir no calculo da médiana, logo assim sabendo
#a médiana, inserimos nos valores 96 e 98 que seria 0.

# %%
bc['NumberOfTimes90DaysLate'].value_counts().sort_index(ascending=False)
# Out:
# NumberOfTimes90DaysLate
# 98      213
# 96        1
# 18        1
# 17        1
# 16        1
# 12        1
# 11        1
# 10        2
# 9        14
# 8        19
# 7        26
# 6        44
# 5       102
# 4       191
# 3       445
# 2      1062
# 1      3594
# 0     95784
# Name: count, dtype: int64

# %%
bc['Sentinela90_atrasado']=bc['NumberOfTimes90DaysLate'].isin([96,98]).astype(int)

# %%
bc['NumberOfTimes90DaysLate']=bc['NumberOfTimes90DaysLate'].replace([96,98], np.nan)

# %%
bc['NumberOfTimes90DaysLate'].median()
# Out:
# 0.0

# %%
bc['NumberOfTimes90DaysLate']=bc['NumberOfTimes90DaysLate'].fillna(bc['NumberOfTimes90DaysLate'].median())

# %%
bc.head(55)
# Out:
#     Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                 0                              0.885519   43
# 1            2                 0                              0.463295   57
# 2            3                 0                              0.043275   59
# 3            4                 0                              0.280308   38
# 4            5                 0                              1.000000   27
# 5            6                 0                              0.509791   63
# 6            7                 0                              0.587778   50
# 7            8                 0                              0.046149   79
# 8            9                 0                              0.013527   68
# 9           10                 0                              1.000000   23
# 10          11                 0                              0.028485   37
# ...

# %%
bc.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  101502.000000          101502.0                         101502.000000
# mean    50751.957804               0.0                              0.301650
# std     29301.677781               0.0                              0.336598
# min         1.000000               0.0                              0.000000
# 25%     25376.250000               0.0                              0.030131
# 50%     50751.500000               0.0                              0.143128
# 75%     76127.750000               0.0                              0.512504
# max    101503.000000               0.0                              1.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  101502.000000                         101502.000000  101502.000000
# mean       52.405490                              0.289344       0.295642
# ...

# %%
#  Em 'NumberRealEstateLoansOrLines' parece estar tudo correto, sem correspondência de outliers e sem número nulos, os números altos correspodem a altas
# rendas mensais e sem 'MonthlyIncome_Modificada'(Rendas nulas).

# %%
bc['NumberRealEstateLoansOrLines'].value_counts().sort_index(ascending=False)
# Out:
# NumberRealEstateLoansOrLines
# 37        1
# 29        1
# 25        1
# 21        1
# 20        1
# 19        2
# 18        1
# 16        2
# 15        4
# 14        9
# 13        5
# 12       11
# 11       19
# 10       23
# 9        49
# 8        58
# 7       108
# 6       227
# 5       452
# 4      1414
# 3      4423
# 2     20955
# 1     35669
# 0     38066
# Name: count, dtype: int64

# %%
print(bc['NumberRealEstateLoansOrLines'].describe())
# Out:
# count    101502.000000
# mean          1.013074
# std           1.110259
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           2.000000
# max          37.000000
# Name: NumberRealEstateLoansOrLines, dtype: float64

# %%
bc['NumberRealEstateLoansOrLines'].isnull().sum()
# Out:
# np.int64(0)

# %%
bc.loc[bc['NumberRealEstateLoansOrLines'] >=15]
# Out:
#        Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 95             96                 0                              0.005575
# 6570         6571                 0                              0.195694
# 8977         8978                 0                              0.079942
# 16895       16896                 0                              0.581460
# 24905       24906                 0                              0.466175
# 30615       30616                 0                              0.225813
# 45850       45851                 0                              0.252866
# 61575       61576                 0                              0.224621
# 63263       63264                 0                              0.011351
# 75452       75453                 0                              0.197780
# 87260       87261                 0                              0.481516
# 87339       87340                 0                              0.279738
# ...

# %%
#  Em 'NumberOfTime60-89DaysPastDueNotWorse' é possivel identicar alguns outliers que são correspondentes a 'RevolvingUtilizationOfUnsecuredLines',
#'NumberOfTime30-59DaysPastDueNotWorse' e 'Sentinela90_atrasado' onde todos correspondem a mesma coisa, sendo assim coerente remover todas as linhas 
#entre 96 e 98 de 'NumberOfTime60-89DaysPastDueNotWorse' correspondente a outras tabelas.

# %%
bc['NumberOfTime60-89DaysPastDueNotWorse'].value_counts().sort_index(ascending=False)
# Out:
# NumberOfTime60-89DaysPastDueNotWorse
# 98      213
# 96        1
# 9         3
# 8         1
# 7         7
# 6         7
# 5        25
# 4        61
# 3       216
# 2       731
# 1      3863
# 0     96374
# Name: count, dtype: int64

# %%
bc['NumberOfTime60-89DaysPastDueNotWorse'].describe()
# Out:
# count    101502.00000
# mean          0.27032
# std           4.50360
# min           0.00000
# 25%           0.00000
# 50%           0.00000
# 75%           0.00000
# max          98.00000
# Name: NumberOfTime60-89DaysPastDueNotWorse, dtype: float64

# %%
bc['NumberOfTime60-89DaysPastDueNotWorse'].isnull().sum()
# Out:
# np.int64(0)

# %%
bc.loc[bc['NumberOfTime60-89DaysPastDueNotWorse'] >= 96].sort_values(by='NumberOfTime60-89DaysPastDueNotWorse',ascending=True).head(40)
# Out:
#        Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 14534       14535                 0                                   1.0
# 9              10                 0                                   1.0
# 307           308                 0                                   1.0
# 69             70                 0                                   1.0
# 1131         1132                 0                                   1.0
# 1166         1167                 0                                   1.0
# 1176         1177                 0                                   1.0
# 703           704                 0                                   1.0
# 1924         1925                 0                                   1.0
# 2265         2266                 0                                   1.0
# 2667         2668                 0                                   1.0
# 3088         3089                 0                                   1.0
# ...

# %%
mask = bc['NumberOfTime60-89DaysPastDueNotWorse'] >=96

# %%
bc[mask]['NumberOfTime30-59DaysPastDueNotWorse'].value_counts()
# Out:
# NumberOfTime30-59DaysPastDueNotWorse
# 20    214
# Name: count, dtype: int64

# %%
bc[mask]['RevolvingUtilizationOfUnsecuredLines'].value_counts()
# Out:
# RevolvingUtilizationOfUnsecuredLines
# 1.0    214
# Name: count, dtype: int64

# %%
bc[mask]['NumberOfOpenCreditLinesAndLoans'].value_counts()
# Out:
# NumberOfOpenCreditLinesAndLoans
# 0    213
# 1      1
# Name: count, dtype: int64

# %%
corrompidos = bc['NumberOfTime60-89DaysPastDueNotWorse'].isin([96, 98])

# %%
 bc=bc[~corrompidos].reset_index(drop=True)

# %%
bc.loc[bc['NumberOfTime60-89DaysPastDueNotWorse'] >=96]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, SeriousDlqin2yrs, RevolvingUtilizationOfUnsecuredLines, age, NumberOfTime30-59DaysPastDueNotWorse, DebtRatio, MonthlyIncome, NumberOfOpenCreditLinesAndLoans, NumberOfTimes90DaysLate, NumberRealEstateLoansOrLines, NumberOfTime60-89DaysPastDueNotWorse, NumberOfDependents, MonthlyIncome_Modificada, Sentinela90_atrasado]
# Index: []

# %%
bc.head(30)
# Out:
#     Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0            1                 0                              0.885519   43
# 1            2                 0                              0.463295   57
# 2            3                 0                              0.043275   59
# 3            4                 0                              0.280308   38
# 4            5                 0                              1.000000   27
# 5            6                 0                              0.509791   63
# 6            7                 0                              0.587778   50
# 7            8                 0                              0.046149   79
# 8            9                 0                              0.013527   68
# 9           11                 0                              0.028485   37
# 10          12                 0                              0.085077   52
# ...

# %%
bc.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  101288.000000          101288.0                         101288.000000
# mean    50757.480225               0.0                              0.300175
# std     29302.650323               0.0                              0.335417
# min         1.000000               0.0                              0.000000
# 25%     25380.750000               0.0                              0.029994
# 50%     50757.500000               0.0                              0.143128
# 75%     76137.250000               0.0                              0.509003
# max    101503.000000               0.0                              1.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  101288.000000                         101288.000000  101288.000000
# mean       52.445443                              0.247700       0.296215
# ...

# %%
#  Verificando a tabela 'NumberOfDependents' é notavel os valores 43 e 20 muito altos e isolados dos normais e tambem presença de valores Nulos.
# Com isso, é necessário a criação de uma outra tabela('Nulos_NumberOfDependents') dos valores Nulos com 1 e 0 sendo 1 na presença de valores Nulos.
# Logo em seguida calcular a mediana da tabela 'NumberOfDependents' e colocar na tabela principal, sendo a mediana como 1 na tabela 'Nulos_NumberOfDependents'.
# E também limitar em 10 o valor máximo da tabela 'NumberOfDependents'.

# %%
bc['NumberOfDependents'].value_counts().sort_index(ascending=False)
# Out:
# NumberOfDependents
# 43.0        1
# 20.0        1
# 10.0        3
# 9.0         3
# 8.0        16
# 7.0        50
# 6.0       125
# 5.0       526
# 4.0      1992
# 3.0      6617
# 2.0     13282
# 1.0     17598
# 0.0     58471
# Name: count, dtype: int64

# %%
bc['NumberOfDependents'].isnull().sum()
# Out:
# np.int64(2603)

# %%
bc.loc[bc['NumberOfDependents'] == 2].sort_values(by = 'NumberOfDependents',ascending=True).head(15)
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 101275      101491                 0                              0.875649
# 101267      101482                 0                              0.048971
# 101264      101479                 0                              0.000000
# 101261      101476                 0                              1.000000
# 101248      101463                 0                              0.029086
# 101238      101453                 0                              0.055424
# 101237      101452                 0                              0.000000
# 101227      101442                 0                              0.240630
# 101224      101439                 0                              0.059631
# 101211      101426                 0                              0.176939
# 101209      101424                 0                              0.798160
# ...

# %%
bc['Nulos_NumberOfDependents']=bc['NumberOfDependents'].isna().astype(int)

# %%
bc.loc[bc['Nulos_NumberOfDependents'] ==1]
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 45              47                 0                              0.013049
# 78              81                 0                              0.085647
# 196            199                 0                              0.024887
# 236            239                 0                              0.000000
# 248            251                 0                              1.000000
# ...            ...               ...                                   ...
# 100932      101146                 0                              0.000000
# 101174      101389                 0                              0.012208
# 101217      101432                 0                              0.076296
# 101246      101461                 0                              1.000000
# 101285      101501                 0                              0.081596
#
# ...

# %%
bc['NumberOfDependents'].median()
# Out:
# 0.0

# %%
bc['NumberOfDependents'].fillna(bc['NumberOfDependents'].median(),inplace=True)

# %%
bc.loc[bc['NumberOfDependents'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, SeriousDlqin2yrs, RevolvingUtilizationOfUnsecuredLines, age, NumberOfTime30-59DaysPastDueNotWorse, DebtRatio, MonthlyIncome, NumberOfOpenCreditLinesAndLoans, NumberOfTimes90DaysLate, NumberRealEstateLoansOrLines, NumberOfTime60-89DaysPastDueNotWorse, NumberOfDependents, MonthlyIncome_Modificada, Sentinela90_atrasado, Nulos_NumberOfDependents]
# Index: []

# %%
bc['NumberOfDependents']=bc['NumberOfDependents'].clip(upper=10)

# %%
--------------------------------------------------------------------------------------------------------------------------------------------------------
